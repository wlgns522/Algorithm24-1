# %% [markdown]
# # 카운팅 정렬

# %% [markdown]
# ### 1. 문제 정의

# %% [markdown]
#  - 문제 이름 : 알파벳 소문자와 대문자(a~z, A~Z)만으로 이루어진 리스트를 알파벳 순으로 정렬하는 코드를 카운팅 정렬로 구현하라
#  - 문제 설명 : 카운팅 정렬을 사용하여 소문자a~z,대문자A~Z순으로 정렬하기

# %% [markdown]
# ### 2. 알고리즘 설명

# %% [markdown]
# 문자열에서 알파벳의 갯수를 저장할 카운트 배열을 초기화 하고 문자열을 순회하면서 각 문자의 갯수를 몇개인지 기록하고 카운트 배열을 합 배열로 변환하여 알파벳의 최종 위치를 계산하고 입력 문자열을 역순회 하면서 문자를 정렬된 위치에 저장한다.

# %% [markdown]
# ### 3.손으로 푼 예제

# %% [markdown]
# ![KakaoTalk_20240530_222303412.jpg](attachment:KakaoTalk_20240530_222303412.jpg)

# %% [markdown]
# ### 4. 코드 개요

# %% [markdown]
#  - 입력 변수 : 정렬할 문자열
#  - 출력 : 정렬된 문자열
#  - 함수 : counting_sort_alphabet_case

# %% [markdown]
# ### 5. 알고리즘 코드

# %%
def counting_sort_alphabet_case(arr):
    count = [0] * 52  
    output = [''] * len(arr)

    for char in arr:
        if 'a' <= char <= 'z':
            count[ord(char) - ord('a')] += 1
        elif 'A' <= char <= 'Z':
            count[ord(char) - ord('A') + 26] += 1

    for i in range(1, 52):
        count[i] += count[i - 1]

    for char in reversed(arr):
        if 'a' <= char <= 'z':
            output[count[ord(char) - ord('a')] - 1] = char
            count[ord(char) - ord('a')] -= 1
        elif 'A' <= char <= 'Z':
            output[count[ord(char) - ord('A') + 26] - 1] = char
            count[ord(char) - ord('A') + 26] -= 1
    
    return ''.join(output)

# %% [markdown]
# ### 6. 테스트 코드

# %%
input_string = "qwertyuiopalskWOEIRUTYAdjKDJFHGZfhgmxncbvzQPLSMXNCBV"
sorted_string = counting_sort_alphabet_case(input_string)
print(f"정렬된 문자열: {sorted_string}")

# %% [markdown]
# ### 7.수행 결과

# %%
def counting_sort_alphabet_case(arr):
    count = [0] * 52  
    output = [''] * len(arr)

    for char in arr:
        if 'a' <= char <= 'z':
            count[ord(char) - ord('a')] += 1
        elif 'A' <= char <= 'Z':
            count[ord(char) - ord('A') + 26] += 1

    for i in range(1, 52):
        count[i] += count[i - 1]

    for char in reversed(arr):
        if 'a' <= char <= 'z':
            output[count[ord(char) - ord('a')] - 1] = char
            count[ord(char) - ord('a')] -= 1
        elif 'A' <= char <= 'Z':
            output[count[ord(char) - ord('A') + 26] - 1] = char
            count[ord(char) - ord('A') + 26] -= 1
    
    return ''.join(output)

input_string = "qwertyuiopalskWOEIRUTYAdjKDJFHGZfhgmxncbvzQPLSMXNCBV"
sorted_string = counting_sort_alphabet_case(input_string)
print(f"정렬된 문자열: {sorted_string}")
# Out:
# 정렬된 문자열: abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %% [markdown]
# ### 8.복잡도 분석

# %% [markdown]
# 문자열의 크기가 카운트 배열에 비해 훨씬 작기 때문에 O(n)이다.
