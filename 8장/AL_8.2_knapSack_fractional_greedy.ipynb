# %% [markdown]
# # 분할 가능한 배낭 채우기

# %% [markdown]
# ### 1. 문제 정의

# %% [markdown]
#  - 문제 이름 : 분할 가능한 배낭 채우기(탐욕적 기법)
#  - 문제 설명 : 탐욕적 기법을 사용하여 물건의 무게와 가치를 비교하여 최대한 많은 물건을 넣는다

# %% [markdown]
# ### 2. 알고리즘 설명

# %% [markdown]
# 물건들의 무게 당 가치를 비교하여 가장 높은 물건부터 배낭에 넣는다

# %% [markdown]
# ### 3. 손으로 푼 예제

# %% [markdown]
# ![KakaoTalk_20240612_111618008.jpg](attachment:KakaoTalk_20240612_111618008.jpg)

# %% [markdown]
# ### 4. 코드 개요

# %% [markdown]
#  - 입력 변수 : 배낭의 용량(W), 물건의 리스트(obj)

# %% [markdown]
# ### 5. 알고리즘 코드

# %%
def knapSack_fractional_greedy(obj, W):
    obj.sort(key = lambda o: o[2]/o[1], reverse=Ture)

totalValue = 0
for o in obj :
    if W <= 0: break
    if W - o[1] >=0:
        W -= o[1]
        totalValue += o[2]
    else:
        fraction = W / o[1]
        totalValue += o[2] * fraction
        W = int(W - (o[1] * fraction))
    
return totalValue

# %% [markdown]
# ### 6. 테스트 코드

# %%
obj = [ ("A", 10, 80), ("B", 12, 120), ("C", 8, 60)]
print("W = 18", obj)
print("부분적인배낭(18): ", kanpSack_fractional_greedy(obj,18), end='\n\n')

obj = [ ("A", 10,60), ("B", 40,40),("C", 20,100),("D", 30,120)]
print("W = 50", obj)
print("부분적인배낭(50):", knapSack_fractional_greedy(obj,50))

# %% [markdown]
# ### 7. 수행 결과

# %%
def knapSack_fractional_greedy(obj, W):
    obj.sort(key=lambda o: o[2] / o[1], reverse=True)

    totalValue = 0
    for o in obj:
        if W <= 0:
            break
        if W - o[1] >= 0:
            W -= o[1]
            totalValue += o[2]
        else:
            fraction = W / o[1]
            totalValue += o[2] * fraction
            W -= int(o[1] * fraction)

    return totalValue

obj = [("A", 10, 80), ("B", 12, 120), ("C", 8, 60)]
print("W = 18", obj)
print("부분적인배낭(18): ", knapSack_fractional_greedy(obj, 18), end='\n\n')

obj = [("A", 10, 60), ("B", 40, 40), ("C", 20, 100), ("D", 30, 120)]
print("W = 50", obj)
print("부분적인배낭(50):", knapSack_fractional_greedy(obj, 50))
# Out:
# W = 18 [('A', 10, 80), ('B', 12, 120), ('C', 8, 60)]
# 부분적인배낭(18):  168.0
#
# W = 50 [('A', 10, 60), ('B', 40, 40), ('C', 20, 100), ('D', 30, 120)]
# 부분적인배낭(50): 240.0

# %% [markdown]
# ### 8. 복잡도 분석

# %% [markdown]
# n개의 물건이 주어지는 경우, 2행에서 정렬이 필요하므로 nO(n log_2 n)
# 이 과정을 n번 반복하는 5행의 루프 하나뿐이므로 O(n)
# 전체의 시간 복잡도는 정렬 방법에 달려 있기에 O(n log_2 n)이다
